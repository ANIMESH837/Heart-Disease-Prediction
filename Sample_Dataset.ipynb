# %%
import pandas as pd
import os

print("Creating Heart Disease Dataset...")

data = [
    [63,1,3,145,233,1,0,150,0,2.3,0,0,1,1],
    [67,1,0,160,286,0,0,108,1,1.5,1,3,2,0],
    [67,1,0,120,229,0,0,129,1,2.6,1,2,3,0],
    [37,1,2,130,250,0,1,187,0,3.5,0,0,2,1],
    [41,0,1,130,204,0,0,172,0,1.4,2,0,2,1],
    [56,1,1,120,236,0,1,178,0,0.8,2,0,2,1],
    [62,0,0,140,268,0,0,160,0,3.6,0,2,2,0],
    [57,0,0,120,354,0,1,163,1,0.6,2,0,2,1],
    [63,1,0,130,254,0,0,147,0,1.4,1,1,3,0],
    [53,1,0,140,203,1,0,155,1,3.1,0,0,3,0],
    [57,1,0,140,192,0,1,148,0,0.4,1,0,1,1],
    [56,0,1,140,294,0,0,153,0,1.3,1,0,2,1],
    [44,1,1,120,263,0,1,173,0,0.0,2,0,3,1],
    [56,1,1,130,256,1,0,142,1,0.6,1,1,1,1],
    [44,1,2,130,233,0,1,179,1,0.4,2,0,2,1],
    [48,1,2,124,255,1,1,175,0,0.0,2,2,2,1],
    [49,1,1,130,266,0,1,171,0,0.6,2,0,2,1],
    [54,1,0,140,239,0,1,160,0,1.2,2,0,2,1],
    [43,1,0,115,303,0,1,181,0,1.2,1,0,2,1],
    [42,0,2,120,209,0,1,173,0,0.0,1,0,2,1],
    [54,1,0,120,188,0,1,113,0,1.4,1,1,3,0],
    [44,1,0,112,290,0,0,153,0,0.0,2,1,2,0],
    [51,1,2,110,175,0,1,123,0,0.6,2,0,2,1],
    [65,0,0,140,417,1,0,157,0,0.8,2,1,2,1],
    [53,1,2,130,246,1,0,173,0,0.0,2,3,2,1],
    [41,0,1,105,198,0,1,168,0,0.0,2,0,2,1],
    [56,1,1,120,240,0,1,169,0,0.0,0,0,2,1],
    [51,1,2,120,295,0,0,157,0,0.6,2,0,2,1],
    [59,1,0,134,204,0,1,162,0,0.8,2,2,2,0],
    [34,0,1,118,210,0,1,192,0,0.7,2,0,2,1]
]

columns = [
    "age","sex","cp","trestbps","chol","fbs",
    "restecg","thalach","exang","oldpeak",
    "slope","ca","thal","target"
]

df = pd.DataFrame(data, columns=columns)

print("\nDataset Shape:")
print(df.shape)

print("\nFirst 5 Rows:")
print(df.head())


df.to_pickle("heart_disease_dataset.pkl")

print("\nDataset saved successfully!")
print("File: heart_disease_dataset.pkl")

print("\nCurrent Working Directory:")
print(os.getcwd())
# Out:
# Creating Heart Disease Dataset...
#
# Dataset Shape:
# (30, 14)
#
# First 5 Rows:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   67    1   0       160   286    0        0      108      1      1.5      1
# 2   67    1   0       120   229    0        0      129      1      2.6      1
# 3   37    1   2       130   250    0        1      187      0      3.5      0
# 4   41    0   1       130   204    0        0      172      0      1.4      2
#
#    ca  thal  target
# 0   0     1       1
# 1   3     2       0
# 2   2     3       0
# 3   0     2       1
# 4   0     2       1
#
# Dataset saved successfully!
# File: heart_disease_dataset.pkl
#
# Current Working Directory:
# c:\Users\OMEN\OneDrive\Desktop\Heart Disease Prediction\Heart-Disease-Prediction
